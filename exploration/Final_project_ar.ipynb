# %% [markdown]
# Import Kaggle Data

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Run this cell to mount your drive (you will be prompted to sign in)
from google.colab import drive
drive.mount('/content/drive')

# Create the kaggle directory and read the uploaded kaggle.json file
# (NOTE: Do NOT run this cell more than once unless restarting kernel)
# !mkdir ~/.kaggle
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# Read the uploaded kaggle.json file
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/

# %%
# Download dataset
# !kaggle datasets download -d Cornell-University/arxiv
# Out:
# arxiv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Unzip folder in Colab content folder
# !unzip /content/arxiv.zip
# Out:
# Archive:  /content/arxiv.zip
# replace arxiv-metadata-oai-snapshot.json? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
f = open('/content/arxiv-metadata-oai-snapshot.json', "r")
data = json.loads(f.read())

# %% [markdown]
# Import Google Cloud Public Datasets

# %%
# etitle Setup 
from google.colab import auth 
from google.cloud import bigquery
from google.colab import data_table
project = 'phonic-client-209005' 
location = 'US' 
client = bigquery.Client(project=project, location=location)
auth.authenticate_user()

# %%
sql_query = ('''SELECT *
                FROM bigquery-public-data.labeled_patents.extracted_data''')
extracted_data = client.query(sql_query).to_dataframe()
sql_query = ('''SELECT *
                FROM bigquery-public-data.labeled_patents.figures''')
figures = client.query(sql_query).to_dataframe()
sql_query = ('''SELECT *
                FROM bigquery-public-data.labeled_patents.invention_types''')
invention_types = client.query(sql_query).to_dataframe()

# %%
extracted_data.head()
# Out:
#                                             gcs_path issuer language  \
# 0  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 1  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 2  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 3  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 4  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
#
#   publication_date class_international class_us application_number  \
# 0        29.08.018           E04H 6/12     None         18157874.1
# 1       03.10.2018          G06F 11/30     None         18157347.8
# 2       03.10.2018          A01K 31/00     None         18171005.4
# 3       03.10.2018          H01L 21/20     None         18166536.5
# 4       03.10.2018           H05B 6/12     None         18165514.3
#
#   filing_date priority_date_eu          representative_line_1_eu  \
# 0  21.02.2018       22.02.2017  Liedtke & Partner Patentanw√§lte
# ...

# %%
figures.head()
# Out:
#                                             gcs_path  x_relative_min  \
# 0  gs://gcs-public-data--labeled-patents/espacene...        0.356322
# 1  gs://gcs-public-data--labeled-patents/espacene...        0.395039
# 2  gs://gcs-public-data--labeled-patents/espacene...        0.358137
# 3  gs://gcs-public-data--labeled-patents/espacene...        0.539020
# 4  gs://gcs-public-data--labeled-patents/espacene...        0.531155
#
#    y_relative_min  x_relative_max  y_relative_max
# 0        0.745275        0.669691        0.936856
# 1        0.682131        0.640048        0.935567
# 2        0.637457        0.664247        0.935567
# 3        0.600945        0.882638        0.955326
# 4        0.597079        0.888082        0.923110

# %%
invention_types.head()
# Out:
#                                            gcs_path invention_type
# 0  gs://gcs-public-data--labeled-patents/us_061.pdf          other
# 1  gs://gcs-public-data--labeled-patents/us_019.pdf          other
# 2  gs://gcs-public-data--labeled-patents/us_001.pdf          other
# 3  gs://gcs-public-data--labeled-patents/us_068.pdf          other
# 4  gs://gcs-public-data--labeled-patents/us_076.pdf          other
